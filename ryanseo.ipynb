# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df1 = pd.read_excel(r"C:\Users\user\Downloads\아이브코리아\IVE_시간별_적립_보고서.xlsx")
df2 = pd.read_excel(r"C:\Users\user\Downloads\아이브코리아\IVE_광고참여정보.xlsx")
df3 = pd.read_excel(r"C:\Users\user\Downloads\아이브코리아\IVE_광고적립.xlsx")
df4 = pd.read_excel(r"C:\Users\user\Downloads\아이브코리아\IVE_광고목록.xlsx")

# %%
dfs = {
    "시간별_적립_보고서": df1,
    "광고참여정보": df2,
    "광고적립": df3,
    "광고목록": df4
}

import pandas as pd

shapes = pd.DataFrame(
    {name: df.shape for name, df in dfs.items()},
    index=["rows", "columns"]
).T

shapes
# Out:
#                rows  columns
# 시간별_적립_보고서   279916       10
# 광고참여정보      1048575       17
# 광고적립        1048575       15
# 광고목록         445260       30

# %%
for name, df in dfs.items():
    print(f"{name}")
    display(df.info())
# Out:
# 시간별_적립_보고서
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279916 entries, 0 to 279915
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   rpt_time_date   279916 non-null  object
#  1   rpt_time_time   279916 non-null  int64
#  2   ads_idx         279916 non-null  int64
#  3   mda_idx         279916 non-null  int64
#  4   rpt_time_clk    279916 non-null  int64
#  5   rpt_time_turn   279916 non-null  int64
#  6   rpt_time_scost  279916 non-null  int64
#  7   rpt_time_acost  279916 non-null  int64
#  8   rpt_time_cost   279916 non-null  int64
#  9   rpt_time_earn   279916 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 21.4+ MB
# None
# 광고참여정보
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
# ...

# %%
for name, df in dfs.items():
    print(f"{name}")
    display(df.isnull().sum())
# Out:
# 시간별_적립_보고서
# rpt_time_date     0
# rpt_time_time     0
# ads_idx           0
# mda_idx           0
# rpt_time_clk      0
# rpt_time_turn     0
# rpt_time_scost    0
# rpt_time_acost    0
# rpt_time_cost     0
# rpt_time_earn     0
# dtype: int64
# 광고참여정보
# click_key               0
# ads_idx                 0
# dvc_idx                 0
# mda_idx                 0
# pub_sub_rel_id          0
# adv_price               0
# contract_price          0
# media_price             0
# reward_price            0
# reward_point            0
# click_day               0
# click_time              0
# click_date              0
# exp_day                 0
# network            155389
# carrier           1004187
# user_ip                 2
# dtype: int64
# 광고적립
# rwd_idx              0
# ads_idx              0
# ads_code             0
# mda_idx              0
# pub_sub_rel_id       0
# dvc_idx              0
# advid             7094
# click_key            0
# show_cost            0
# ...

# %%
df4.head(10)
# Out:
#    ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  ads_category  \
# 0      160  tr71opm6C1        6       10    13604         1             1
# 1      284  xlNpfkgtLX        6       10    13605         1             1
# 2      292  7Hj8V5QKiy        6       10    13606         1             1
# 3      304  1RfxHJcuEe        6       10    13607         2             1
# 4      306  l3GyilYEVk        6       10    23543         1             1
# 5      310  cSsBPD7gOe        6       10    13608         2             1
# 6      534  UEwz350UoE        6       10       42         1             1
# 7     1142  zQ76Efhdj3        9        0        0         3             0
# 8     1162  ECKwDa107E        9       22       40         2             1
# 9     1164  eQJQGBKFWz        9       30      762         2             1
#
#                        ads_name  \
# 0                      리니지레드나이츠
# 1          강철의함대:Ocean Overlord
# 2                      스노우 SNOW
# ...

# %%
df1
# Out:
#        rpt_time_date  rpt_time_time  ads_idx  mda_idx  rpt_time_clk  \
# 0         2025-07-27              0    11059      398             5
# 1         2025-07-27              0    13209      583             3
# 2         2025-07-27              0    13928      303             3
# 3         2025-07-27              0    13928      324             3
# 4         2025-07-27              0    13928      340             6
# ...              ...            ...      ...      ...           ...
# 279911    2025-08-25             11   446855      563            15
# 279912    2025-08-25             11   446902      270             1
# 279913    2025-08-25             11   446909      562             3
# 279914    2025-08-25             11   446909      563            51
# 279915    2025-08-25             11   446917      270             1
#
#         rpt_time_turn  rpt_time_scost  rpt_time_acost  rpt_time_cost  \
# 0                   0               0               0              0
# ...

# %%
df2
# Out:
#                                         click_key  ads_idx   dvc_idx  mda_idx  \
# 0        000000d54b9faad47ee99d6cd3cf53894dd4baa5   313780  61906528      539
# 1        000002b4d92f7648b455877c2676452efcd22a09   412426  34422806       58
# 2        0000057e97361ff3d0263aaecee34cfaa3ba30fb   443660  38366075      808
# 3        00000607f60139015da3ee1dd5499db3faa100dc   360192  61894110      539
# 4        0000066bc25d4a6d147c27326cf972a4de88024e   372307  61956954      539
# ...                                           ...      ...       ...      ...
# 1048570  0fe9ffbe93044e7f77c35ab6803d507f60f26902   264409  61913949      539
# 1048571  0fea011c0d2f2ec5fa8fd26f4e8dc69ef55c9493   360192  61905802      539
# 1048572  0fea03563fbbe241a12acfe58045018b80ecb5b7   360192  61897624      539
# 1048573  0fea0642bfeebab4b76468e305d0ac0134288c7c   388989  61943312      539
# 1048574  0fea067bc08026cc121324ca18cbaf40c8c1f116    28025  61747080      539
#
# ...

# %%
df3
# Out:
#            rwd_idx  ads_idx    ads_code  mda_idx  pub_sub_rel_id   dvc_idx  \
# 0        238304818   413490  CFZ6lzEmeD       22        27496512  32947806
# 1        238304829   413490  CFZ6lzEmeD       22        27496512  47387244
# 2        238304816   413490  CFZ6lzEmeD       22        27496512  32425124
# 3        238304817   413490  CFZ6lzEmeD       22        27496513  34006545
# 4        238304802   133653  rl8ud4uNQC      801               1  56867331
# ...            ...      ...         ...      ...             ...       ...
# 1048570  239352265   444349  WX4BWfxRA8      343        11082141  60393702
# 1048571  239352095   445046  squ3n89SHT       58        33306660  56803432
# 1048572  239352303   445047  squ3n89SHT      343        11082141  51025931
# 1048573  239352646   444349  WX4BWfxRA8      342        11082141  49791836
# 1048574  239352702   444349  WX4BWfxRA8      342        11082141  52848852
#
#                                         advid  \
# ...

# %%
df4
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 0           160  tr71opm6C1        6       10    13604         1
# 1           284  xlNpfkgtLX        6       10    13605         1
# 2           292  7Hj8V5QKiy        6       10    13606         1
# 3           304  1RfxHJcuEe        6       10    13607         2
# 4           306  l3GyilYEVk        6       10    23543         1
# ...         ...         ...      ...      ...      ...       ...
# 445255   446914  qy1HUatIL9       85     1631  1223705         3
# 445256   446915  UKnGFJUnmg       84     1623  1223706         3
# 445257   446916  g3lUg3nuxR       86     1655  1223708         3
# 445258   446917  0GLHsRVZNv       57       84  1223711         3
# 445259   446918  k2YLVkNAuO       57       84  1223710         3
#
#         ads_category                                          ads_name  \
# 0                  1                                          리니지레드나이츠
# ...
